# %%
# !pip install trdg Pillow==9.5.0
# Out:
# ...
# WARNING: There was an error checking the latest version of pip.

# %%
from trdg.generators import (
    GeneratorFromDict,
    GeneratorFromRandom,
    GeneratorFromStrings,
    GeneratorFromWikipedia,
)
# Out:
# Missing modules for handwritten text generation.

# %%
import matplotlib.pyplot as plt

# %%
import cv2

# %%
# The generators use the same arguments as the CLI, only as parameters
generator = GeneratorFromRandom(
    count=10,

)

i = 0
with open('gt_text.txt', 'a', encoding='utf-8') as file:
    for img, lbl in generator:
        print(img)
        file.write(f"{lbl}.jpg" + " " + lbl + '\n')
        # cv2.imwrite(f"/Synth/image/{lbl}.png", img)
        img.save(f"../dataests/synth/image/{i}.jpg")
        i += 1
# Out:
# <PIL.Image.Image image mode=RGB size=29x32 at 0x176A0FE00>
# <PIL.Image.Image image mode=RGB size=55x32 at 0x176A0CDA0>
# <PIL.Image.Image image mode=RGB size=85x32 at 0x176A0E450>
# <PIL.Image.Image image mode=RGB size=55x32 at 0x176A0DBE0>
# <PIL.Image.Image image mode=RGB size=64x32 at 0x176A0CDA0>
# <PIL.Image.Image image mode=RGB size=87x32 at 0x176A0E390>
# <PIL.Image.Image image mode=RGB size=57x32 at 0x176A0C050>
# <PIL.Image.Image image mode=RGB size=90x32 at 0x1695D75C0>
# <PIL.Image.Image image mode=RGB size=63x32 at 0x176A0D190>
# <PIL.Image.Image image mode=RGB size=42x32 at 0x16938EC30>
